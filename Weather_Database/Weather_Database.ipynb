# %%
import random
import numpy as np
import pandas as pd

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
from citipy import citipy

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 760

# %%
import requests

# %%
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
       # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        #print(city_weather)
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_description})
                          #"Date": city_date})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 1 | port lincoln
# Processing Record 3 of Set 1 | tabarqah
# City not found. Skipping...
# Processing Record 4 of Set 1 | katangli
# Processing Record 5 of Set 1 | alice
# Processing Record 6 of Set 1 | balikpapan
# Processing Record 7 of Set 1 | aswan
# Processing Record 8 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | viransehir
# Processing Record 11 of Set 1 | lebu
# Processing Record 12 of Set 1 | srednekolymsk
# Processing Record 13 of Set 1 | pelym
# Processing Record 14 of Set 1 | kahului
# Processing Record 15 of Set 1 | bluff
# Processing Record 16 of Set 1 | arraial do cabo
# Processing Record 17 of Set 1 | rabo de peixe
# Processing Record 18 of Set 1 | hilo
# Processing Record 19 of Set 1 | fort nelson
# Processing Record 20 of Set 1 | jamestown
# Processing Record 21 of Set 1 | kapaa
# Processing Record 22 of Set 1 | divnomorskoye
# Processing Record 23 of Set 1 | macusani
# Processing Record 24 of Set 1 | quatre cocos
# Processing Record 25 of Set 1 | pyapon
# Processing Record 26 of Set 1 | progreso
# Processing Record 27 of Set 1 | saint anthony
# Processing Record 28 of Set 1 | saint-philippe
# Processing Record 29 of Set 1 | gavojdia
# Processing Record 30 of Set 1 | puerto ayora
# Processing Record 31 of Set 1 | fortuna
# Processing Record 32 of Set 1 | calama
# Processing Record 33 of Set 1 | grindavik
# Processing Record 34 of Set 1 | airai
# Processing Record 35 of Set 1 | port alfred
# Processing Record 36 of Set 1 | mayo
# Processing Record 37 of Set 1 | gizo
# Processing Record 38 of Set 1 | rikitea
# Processing Record 39 of Set 1 | carnarvon
# Processing Record 40 of Set 1 | east london
# Processing Record 41 of Set 1 | touros
# Processing Record 42 of Set 1 | qaanaaq
# Processing Record 43 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 1 | albany
# Processing Record 45 of Set 1 | saint george
# Processing Record 46 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 1 | victoria
# Processing Record 48 of Set 1 | bethel
# Processing Record 49 of Set 1 | mahebourg
# Processing Record 50 of Set 1 | codrington
# Processing Record 1 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 2 | svetlogorsk
# Processing Record 3 of Set 2 | butaritari
# Processing Record 4 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 2 | cape town
# Processing Record 6 of Set 2 | kodiak
# Processing Record 7 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 8 of Set 2 | tidore
# City not found. Skipping...
# Processing Record 9 of Set 2 | salaverry
# Processing Record 10 of Set 2 | ushuaia
# Processing Record 11 of Set 2 | lorengau
# Processing Record 12 of Set 2 | mar del plata
# Processing Record 13 of Set 2 | vilyuysk
# Processing Record 14 of Set 2 | ribeira grande
# Processing Record 15 of Set 2 | mazamari
# Processing Record 16 of Set 2 | dikson
# Processing Record 17 of Set 2 | punta arenas
# Processing Record 18 of Set 2 | anloga
# Processing Record 19 of Set 2 | esperance
# Processing Record 20 of Set 2 | atuona
# Processing Record 21 of Set 2 | epe
# Processing Record 22 of Set 2 | georgetown
# Processing Record 23 of Set 2 | kerki
# City not found. Skipping...
# Processing Record 24 of Set 2 | cabo san lucas
# Processing Record 25 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 2 | katsuura
# Processing Record 27 of Set 2 | bushehr
# Processing Record 28 of Set 2 | hobart
# Processing Record 29 of Set 2 | vostok
# Processing Record 30 of Set 2 | avera
# Processing Record 31 of Set 2 | longyearbyen
# Processing Record 32 of Set 2 | biak
# Processing Record 33 of Set 2 | souillac
# Processing Record 34 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 35 of Set 2 | piacabucu
# Processing Record 36 of Set 2 | camacha
# Processing Record 37 of Set 2 | puebla
# Processing Record 38 of Set 2 | atherton
# Processing Record 39 of Set 2 | tianpeng
# Processing Record 40 of Set 2 | panacan
# Processing Record 41 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 2 | zyryanka
# Processing Record 43 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 44 of Set 2 | kununurra
# Processing Record 45 of Set 2 | rapid valley
# Processing Record 46 of Set 2 | chuy
# Processing Record 47 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 2 | isetskoye
# Processing Record 49 of Set 2 | mataura
# Processing Record 50 of Set 2 | pacific grove
# Processing Record 1 of Set 3 | iqaluit
# Processing Record 2 of Set 3 | laguna
# Processing Record 3 of Set 3 | west bay
# Processing Record 4 of Set 3 | kutum
# Processing Record 5 of Set 3 | barrow
# Processing Record 6 of Set 3 | lensk
# Processing Record 7 of Set 3 | oakdale
# Processing Record 8 of Set 3 | archidona
# Processing Record 9 of Set 3 | buala
# Processing Record 10 of Set 3 | pevek
# Processing Record 11 of Set 3 | ambilobe
# Processing Record 12 of Set 3 | vaini
# Processing Record 13 of Set 3 | glossa
# Processing Record 14 of Set 3 | troitsko-pechorsk
# Processing Record 15 of Set 3 | saskylakh
# Processing Record 16 of Set 3 | provideniya
# Processing Record 17 of Set 3 | castro
# Processing Record 18 of Set 3 | sahrak
# City not found. Skipping...
# Processing Record 19 of Set 3 | hermanus
# Processing Record 20 of Set 3 | san patricio
# Processing Record 21 of Set 3 | lagoa
# Processing Record 22 of Set 3 | alice springs
# Processing Record 23 of Set 3 | ancud
# Processing Record 24 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 3 | chokurdakh
# Processing Record 26 of Set 3 | tuktoyaktuk
# Processing Record 27 of Set 3 | northam
# Processing Record 28 of Set 3 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 29 of Set 3 | bossangoa
# Processing Record 30 of Set 3 | los llanos de aridane
# Processing Record 31 of Set 3 | kawalu
# Processing Record 32 of Set 3 | hasaki
# Processing Record 33 of Set 3 | laibin
# Processing Record 34 of Set 3 | itaquyry
# Processing Record 35 of Set 3 | viedma
# Processing Record 36 of Set 3 | puerto escondido
# Processing Record 37 of Set 3 | mogadishu
# Processing Record 38 of Set 3 | talaya
# Processing Record 39 of Set 3 | taoudenni
# Processing Record 40 of Set 3 | jiexiu
# Processing Record 41 of Set 3 | comodoro rivadavia
# Processing Record 42 of Set 3 | geraldton
# Processing Record 43 of Set 3 | uyemskiy
# Processing Record 44 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 3 | pachino
# Processing Record 46 of Set 3 | sao filipe
# Processing Record 47 of Set 3 | coihueco
# Processing Record 48 of Set 3 | nganjuk
# Processing Record 49 of Set 3 | kavieng
# Processing Record 50 of Set 3 | beruni
# City not found. Skipping...
# Processing Record 1 of Set 4 | torbay
# Processing Record 2 of Set 4 | kavaratti
# Processing Record 3 of Set 4 | khairagarh
# Processing Record 4 of Set 4 | nyurba
# Processing Record 5 of Set 4 | lompoc
# Processing Record 6 of Set 4 | kargat
# Processing Record 7 of Set 4 | cockburn town
# Processing Record 8 of Set 4 | chimoio
# Processing Record 9 of Set 4 | kushmurun
# Processing Record 10 of Set 4 | new norfolk
# Processing Record 11 of Set 4 | nelson bay
# Processing Record 12 of Set 4 | le port
# Processing Record 13 of Set 4 | paveh
# Processing Record 14 of Set 4 | nikolskoye
# Processing Record 15 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 4 | saldanha
# Processing Record 17 of Set 4 | kaitangata
# Processing Record 18 of Set 4 | malakal
# Processing Record 19 of Set 4 | yirol
# City not found. Skipping...
# Processing Record 20 of Set 4 | kurumkan
# Processing Record 21 of Set 4 | leningradskiy
# Processing Record 22 of Set 4 | thompson
# Processing Record 23 of Set 4 | dwarka
# Processing Record 24 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 4 | arvi
# Processing Record 26 of Set 4 | oktyabrskoye
# Processing Record 27 of Set 4 | springbok
# Processing Record 28 of Set 4 | amantea
# Processing Record 29 of Set 4 | tawzar
# City not found. Skipping...
# Processing Record 30 of Set 4 | gat
# Processing Record 31 of Set 4 | paita
# Processing Record 32 of Set 4 | luderitz
# Processing Record 33 of Set 4 | tual
# Processing Record 34 of Set 4 | denpasar
# Processing Record 35 of Set 4 | banda aceh
# Processing Record 36 of Set 4 | koshurnikovo
# Processing Record 37 of Set 4 | carndonagh
# Processing Record 38 of Set 4 | tingi
# Processing Record 39 of Set 4 | tasiilaq
# Processing Record 40 of Set 4 | wagar
# Processing Record 41 of Set 4 | te anau
# Processing Record 42 of Set 4 | iracoubo
# Processing Record 43 of Set 4 | lavrentiya
# Processing Record 44 of Set 4 | upernavik
# Processing Record 45 of Set 4 | abnub
# Processing Record 46 of Set 4 | hrob
# Processing Record 47 of Set 4 | tutoia
# Processing Record 48 of Set 4 | kruisfontein
# Processing Record 49 of Set 4 | tulum
# Processing Record 50 of Set 4 | saint-pierre
# Processing Record 1 of Set 5 | saint-leu
# Processing Record 2 of Set 5 | nabire
# Processing Record 3 of Set 5 | margate
# Processing Record 4 of Set 5 | taltal
# Processing Record 5 of Set 5 | pisco
# Processing Record 6 of Set 5 | kandrian
# Processing Record 7 of Set 5 | ayni
# Processing Record 8 of Set 5 | mount isa
# Processing Record 9 of Set 5 | dudinka
# Processing Record 10 of Set 5 | natal
# Processing Record 11 of Set 5 | ascension
# Processing Record 12 of Set 5 | smithers
# Processing Record 13 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 5 | karlstad
# Processing Record 15 of Set 5 | katima mulilo
# Processing Record 16 of Set 5 | yellowknife
# Processing Record 17 of Set 5 | aklavik
# Processing Record 18 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 19 of Set 5 | rumford
# Processing Record 20 of Set 5 | tekkali
# Processing Record 21 of Set 5 | tabou
# Processing Record 22 of Set 5 | valentin gomez farias
# Processing Record 23 of Set 5 | usinsk
# Processing Record 24 of Set 5 | sao joao da barra
# Processing Record 25 of Set 5 | avarua
# Processing Record 26 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 5 | canitas
# City not found. Skipping...
# Processing Record 28 of Set 5 | ilulissat
# Processing Record 29 of Set 5 | sandpoint
# Processing Record 30 of Set 5 | cherskiy
# Processing Record 31 of Set 5 | paso de los toros
# Processing Record 32 of Set 5 | dingle
# Processing Record 33 of Set 5 | champasak
# Processing Record 34 of Set 5 | haysville
# Processing Record 35 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 36 of Set 5 | port elizabeth
# Processing Record 37 of Set 5 | santa isabel do rio negro
# Processing Record 38 of Set 5 | calvinia
# Processing Record 39 of Set 5 | makakilo city
# Processing Record 40 of Set 5 | nador
# Processing Record 41 of Set 5 | horsham
# Processing Record 42 of Set 5 | ayan
# Processing Record 43 of Set 5 | meulaboh
# Processing Record 44 of Set 5 | hambantota
# Processing Record 45 of Set 5 | kloulklubed
# Processing Record 46 of Set 5 | kashan
# Processing Record 47 of Set 5 | faanui
# Processing Record 48 of Set 5 | vygonichi
# Processing Record 49 of Set 5 | komsomolskiy
# Processing Record 50 of Set 5 | san carlos de bariloche
# Processing Record 1 of Set 6 | cherepovets
# Processing Record 2 of Set 6 | aksarka
# Processing Record 3 of Set 6 | acarau
# Processing Record 4 of Set 6 | auchi
# Processing Record 5 of Set 6 | riyadh
# Processing Record 6 of Set 6 | juifang
# City not found. Skipping...
# Processing Record 7 of Set 6 | henderson
# Processing Record 8 of Set 6 | tazovskiy
# Processing Record 9 of Set 6 | clyde river
# Processing Record 10 of Set 6 | onega
# Processing Record 11 of Set 6 | upington
# Processing Record 12 of Set 6 | sarny
# Processing Record 13 of Set 6 | padang
# Processing Record 14 of Set 6 | cidreira
# Processing Record 15 of Set 6 | severo-kurilsk
# Processing Record 16 of Set 6 | myitkyina
# Processing Record 17 of Set 6 | luganville
# Processing Record 18 of Set 6 | honiara
# Processing Record 19 of Set 6 | kerchevskiy
# Processing Record 20 of Set 6 | dukat
# Processing Record 21 of Set 6 | shetpe
# Processing Record 22 of Set 6 | sabang
# Processing Record 23 of Set 6 | zaysan
# Processing Record 24 of Set 6 | alto araguaia
# Processing Record 25 of Set 6 | vestbygda
# City not found. Skipping...
# Processing Record 26 of Set 6 | vilcun
# Processing Record 27 of Set 6 | westport
# Processing Record 28 of Set 6 | aleksandrov gay
# Processing Record 29 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 6 | petropavlovskoye
# Processing Record 31 of Set 6 | jalu
# Processing Record 32 of Set 6 | khatanga
# Processing Record 33 of Set 6 | gamba
# Processing Record 34 of Set 6 | salalah
# Processing Record 35 of Set 6 | nicoya
# Processing Record 36 of Set 6 | sao jose da coroa grande
# Processing Record 37 of Set 6 | norfolk
# Processing Record 38 of Set 6 | mangrol
# Processing Record 39 of Set 6 | pedro ii
# Processing Record 40 of Set 6 | thinadhoo
# Processing Record 41 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 6 | foz
# Processing Record 43 of Set 6 | manoel urbano
# Processing Record 44 of Set 6 | kerrville
# Processing Record 45 of Set 6 | coquimbo
# Processing Record 46 of Set 6 | gyorujbarat
# Processing Record 47 of Set 6 | port macquarie
# Processing Record 48 of Set 6 | ngunguru
# Processing Record 49 of Set 6 | cap malheureux
# Processing Record 50 of Set 6 | teguise
# Processing Record 1 of Set 7 | obuasi
# Processing Record 2 of Set 7 | chifeng
# Processing Record 3 of Set 7 | kushima
# Processing Record 4 of Set 7 | richards bay
# Processing Record 5 of Set 7 | neuquen
# Processing Record 6 of Set 7 | itaituba
# Processing Record 7 of Set 7 | hofn
# Processing Record 8 of Set 7 | grafton
# Processing Record 9 of Set 7 | sitka
# Processing Record 10 of Set 7 | prainha
# Processing Record 11 of Set 7 | uzumlu
# City not found. Skipping...
# Processing Record 12 of Set 7 | jiazi
# Processing Record 13 of Set 7 | carutapera
# Processing Record 14 of Set 7 | los angeles
# Processing Record 15 of Set 7 | bredasdorp
# Processing Record 16 of Set 7 | changuinola
# Processing Record 17 of Set 7 | paracuru
# Processing Record 18 of Set 7 | baoding
# Processing Record 19 of Set 7 | paamiut
# Processing Record 20 of Set 7 | katherine
# Processing Record 21 of Set 7 | palauig
# Processing Record 22 of Set 7 | hovd
# Processing Record 23 of Set 7 | virginia beach
# Processing Record 24 of Set 7 | gijon
# Processing Record 25 of Set 7 | grand gaube
# Processing Record 26 of Set 7 | yar-sale
# Processing Record 27 of Set 7 | tiksi
# Processing Record 28 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 29 of Set 7 | narsaq
# Processing Record 30 of Set 7 | krasnoarmeysk
# Processing Record 31 of Set 7 | hay river
# Processing Record 32 of Set 7 | caravelas
# Processing Record 33 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 34 of Set 7 | mount gambier
# Processing Record 35 of Set 7 | plouzane
# Processing Record 36 of Set 7 | sete
# Processing Record 37 of Set 7 | guigue
# Processing Record 38 of Set 7 | yulara
# Processing Record 39 of Set 7 | byron bay
# Processing Record 40 of Set 7 | goderich
# Processing Record 41 of Set 7 | portland
# Processing Record 42 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 43 of Set 7 | mindelheim
# Processing Record 44 of Set 7 | ruza
# Processing Record 45 of Set 7 | araouane
# Processing Record 46 of Set 7 | lata
# Processing Record 47 of Set 7 | indramayu
# Processing Record 48 of Set 7 | doha
# Processing Record 49 of Set 7 | alamogordo
# Processing Record 50 of Set 7 | umm durman
# City not found. Skipping...
# Processing Record 1 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 8 | hervey bay
# Processing Record 3 of Set 8 | fairbanks
# Processing Record 4 of Set 8 | ortakoy
# Processing Record 5 of Set 8 | nanortalik
# Processing Record 6 of Set 8 | sambava
# Processing Record 7 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 8 of Set 8 | talnakh
# Processing Record 9 of Set 8 | constitucion
# Processing Record 10 of Set 8 | miranda
# Processing Record 11 of Set 8 | eyl
# Processing Record 12 of Set 8 | tonj
# Processing Record 13 of Set 8 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 14 of Set 8 | accra
# Processing Record 15 of Set 8 | visaginas
# Processing Record 16 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 8 | porto recanati
# Processing Record 18 of Set 8 | salinopolis
# Processing Record 19 of Set 8 | malinovoye ozero
# Processing Record 20 of Set 8 | awbari
# Processing Record 21 of Set 8 | sur
# Processing Record 22 of Set 8 | oeiras do para
# Processing Record 23 of Set 8 | coolum beach
# Processing Record 24 of Set 8 | zhigansk
# Processing Record 25 of Set 8 | fuerte olimpo
# Processing Record 26 of Set 8 | karwar
# Processing Record 27 of Set 8 | bengkulu
# Processing Record 28 of Set 8 | garbou
# Processing Record 29 of Set 8 | atambua
# Processing Record 30 of Set 8 | kupang
# Processing Record 31 of Set 8 | dingli
# Processing Record 32 of Set 8 | klaksvik
# Processing Record 33 of Set 8 | marienburg
# Processing Record 34 of Set 8 | berlevag
# Processing Record 35 of Set 8 | kropotkin
# Processing Record 36 of Set 8 | karratha
# Processing Record 37 of Set 8 | sola
# Processing Record 38 of Set 8 | ahipara
# Processing Record 39 of Set 8 | atar
# Processing Record 40 of Set 8 | nemuro
# Processing Record 41 of Set 8 | marawi
# Processing Record 42 of Set 8 | invermere
# Processing Record 43 of Set 8 | nuuk
# Processing Record 44 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 45 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 8 | guiren
# Processing Record 47 of Set 8 | north bend
# Processing Record 48 of Set 8 | acapulco
# Processing Record 49 of Set 8 | masterton
# Processing Record 50 of Set 8 | beloha
# Processing Record 1 of Set 9 | ouegoa
# Processing Record 2 of Set 9 | lloydminster
# Processing Record 3 of Set 9 | zastron
# Processing Record 4 of Set 9 | wenling
# Processing Record 5 of Set 9 | novovasylivka
# Processing Record 6 of Set 9 | hualmay
# Processing Record 7 of Set 9 | hamilton
# Processing Record 8 of Set 9 | tumut
# Processing Record 9 of Set 9 | ixtapa
# Processing Record 10 of Set 9 | la orilla
# Processing Record 11 of Set 9 | isangel
# Processing Record 12 of Set 9 | the valley
# Processing Record 13 of Set 9 | dunedin
# Processing Record 14 of Set 9 | zonguldak
# Processing Record 15 of Set 9 | bodden town
# Processing Record 16 of Set 9 | xuddur
# Processing Record 17 of Set 9 | kuopio
# Processing Record 18 of Set 9 | lillooet
# Processing Record 19 of Set 9 | falkenberg
# Processing Record 20 of Set 9 | heishan
# Processing Record 21 of Set 9 | itarema
# Processing Record 22 of Set 9 | kihei
# Processing Record 23 of Set 9 | ilo
# Processing Record 24 of Set 9 | inhambane
# Processing Record 25 of Set 9 | penalva
# Processing Record 26 of Set 9 | rawson
# Processing Record 27 of Set 9 | mao
# Processing Record 28 of Set 9 | cururupu
# Processing Record 29 of Set 9 | burnie
# Processing Record 30 of Set 9 | college
# Processing Record 31 of Set 9 | chumikan
# Processing Record 32 of Set 9 | moram
# Processing Record 33 of Set 9 | alta floresta
# Processing Record 34 of Set 9 | talawdi
# City not found. Skipping...
# Processing Record 35 of Set 9 | santa maria
# Processing Record 36 of Set 9 | ponta do sol
# Processing Record 37 of Set 9 | betare oya
# Processing Record 38 of Set 9 | pochutla
# Processing Record 39 of Set 9 | filingue
# Processing Record 40 of Set 9 | coruripe
# Processing Record 41 of Set 9 | megali panayia
# Processing Record 42 of Set 9 | yarmouth
# Processing Record 43 of Set 9 | heihe
# Processing Record 44 of Set 9 | waingapu
# Processing Record 45 of Set 9 | sinnamary
# Processing Record 46 of Set 9 | tezu
# Processing Record 47 of Set 9 | tuy hoa
# Processing Record 48 of Set 9 | anori
# Processing Record 49 of Set 9 | abu kamal
# Processing Record 50 of Set 9 | anadyr
# Processing Record 1 of Set 10 | port blair
# Processing Record 2 of Set 10 | jinchengjiang
# City not found. Skipping...
# Processing Record 3 of Set 10 | nuevo progreso
# Processing Record 4 of Set 10 | amuntai
# Processing Record 5 of Set 10 | bara
# Processing Record 6 of Set 10 | shaunavon
# Processing Record 7 of Set 10 | san luis
# Processing Record 8 of Set 10 | korampallam
# Processing Record 9 of Set 10 | daru
# Processing Record 10 of Set 10 | tilichiki
# Processing Record 11 of Set 10 | damaturu
# Processing Record 12 of Set 10 | alofi
# Processing Record 13 of Set 10 | haines junction
# Processing Record 14 of Set 10 | gorontalo
# Processing Record 15 of Set 10 | sisimiut
# Processing Record 16 of Set 10 | shigony
# Processing Record 17 of Set 10 | ketchikan
# Processing Record 18 of Set 10 | yarada
# Processing Record 19 of Set 10 | labytnangi
# Processing Record 20 of Set 10 | zarya
# Processing Record 21 of Set 10 | bulawayo
# Processing Record 22 of Set 10 | deputatskiy
# Processing Record 23 of Set 10 | townsville
# Processing Record 24 of Set 10 | kamaishi
# Processing Record 25 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 27 of Set 10 | saint-francois
# Processing Record 28 of Set 10 | healesville
# Processing Record 29 of Set 10 | zhytomyr
# Processing Record 30 of Set 10 | venkatagiri
# Processing Record 31 of Set 10 | beringovskiy
# Processing Record 32 of Set 10 | kostalexis
# Processing Record 33 of Set 10 | bud
# Processing Record 34 of Set 10 | polovinnoye
# Processing Record 35 of Set 10 | gao
# Processing Record 36 of Set 10 | terrasini
# Processing Record 37 of Set 10 | tondon
# Processing Record 38 of Set 10 | clifton
# Processing Record 39 of Set 10 | namatanai
# Processing Record 40 of Set 10 | kimbe
# Processing Record 41 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 10 | sala consilina
# Processing Record 43 of Set 10 | praxedis guerrero
# Processing Record 44 of Set 10 | manakara
# Processing Record 45 of Set 10 | singkang
# Processing Record 46 of Set 10 | quanzhou
# Processing Record 47 of Set 10 | vila velha
# Processing Record 48 of Set 10 | kaeo
# Processing Record 49 of Set 10 | qaqortoq
# Processing Record 50 of Set 10 | kamenka
# Processing Record 1 of Set 11 | rocha
# Processing Record 2 of Set 11 | america dourada
# Processing Record 3 of Set 11 | lai
# Processing Record 4 of Set 11 | botwood
# Processing Record 5 of Set 11 | kargopol
# Processing Record 6 of Set 11 | ullapool
# Processing Record 7 of Set 11 | batticaloa
# Processing Record 8 of Set 11 | bungu
# Processing Record 9 of Set 11 | columbus
# Processing Record 10 of Set 11 | limoncito
# Processing Record 11 of Set 11 | nang rong
# Processing Record 12 of Set 11 | taloda
# Processing Record 13 of Set 11 | luanda
# Processing Record 14 of Set 11 | murray bridge
# Processing Record 15 of Set 11 | yatou
# Processing Record 16 of Set 11 | oistins
# Processing Record 17 of Set 11 | maniitsoq
# Processing Record 18 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 19 of Set 11 | urumqi
# Processing Record 20 of Set 11 | tahoua
# Processing Record 21 of Set 11 | krasnozerskoye
# Processing Record 22 of Set 11 | limon
# Processing Record 23 of Set 11 | vanimo
# Processing Record 24 of Set 11 | ankang
# Processing Record 25 of Set 11 | eenhana
# Processing Record 26 of Set 11 | muyezerskiy
# Processing Record 27 of Set 11 | andenes
# Processing Record 28 of Set 11 | shimoda
# Processing Record 29 of Set 11 | xichang
# Processing Record 30 of Set 11 | madaoua
# Processing Record 31 of Set 11 | bowen
# Processing Record 32 of Set 11 | jijiga
# Processing Record 33 of Set 11 | broome
# Processing Record 34 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 35 of Set 11 | san pedro
# Processing Record 36 of Set 11 | rolim de moura
# City not found. Skipping...
# Processing Record 37 of Set 11 | presidencia roque saenz pena
# Processing Record 38 of Set 11 | challapata
# Processing Record 39 of Set 11 | kirakira
# Processing Record 40 of Set 11 | katobu
# Processing Record 41 of Set 11 | porto velho
# Processing Record 42 of Set 11 | boshnyakovo
# Processing Record 43 of Set 11 | henties bay
# Processing Record 44 of Set 11 | sayansk
# Processing Record 45 of Set 11 | naze
# Processing Record 46 of Set 11 | samdari
# Processing Record 47 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 48 of Set 11 | palu
# Processing Record 49 of Set 11 | yaan
# Processing Record 50 of Set 11 | yuxia
# Processing Record 1 of Set 12 | atasu
# Processing Record 2 of Set 12 | bettiah
# Processing Record 3 of Set 12 | chino valley
# Processing Record 4 of Set 12 | manono
# Processing Record 5 of Set 12 | guerrero negro
# Processing Record 6 of Set 12 | vila franca do campo
# Processing Record 7 of Set 12 | mansehra
# Processing Record 8 of Set 12 | miyako
# Processing Record 9 of Set 12 | reims
# Processing Record 10 of Set 12 | bambous virieux
# Processing Record 11 of Set 12 | norman wells
# Processing Record 12 of Set 12 | arlit
# Processing Record 13 of Set 12 | puerto colombia
# Processing Record 14 of Set 12 | ingham
# Processing Record 15 of Set 12 | balabac
# Processing Record 16 of Set 12 | raseiniai
# Processing Record 17 of Set 12 | ilhabela
# Processing Record 18 of Set 12 | marsa matruh
# Processing Record 19 of Set 12 | tecoanapa
# Processing Record 20 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 21 of Set 12 | port shepstone
# Processing Record 22 of Set 12 | puerto quijarro
# Processing Record 23 of Set 12 | channel-port aux basques
# Processing Record 24 of Set 12 | cabreuva
# Processing Record 25 of Set 12 | turayf
# Processing Record 26 of Set 12 | nishihara
# Processing Record 27 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 28 of Set 12 | asbury park
# Processing Record 29 of Set 12 | ballina
# Processing Record 30 of Set 12 | chupei
# City not found. Skipping...
# Processing Record 31 of Set 12 | ginir
# Processing Record 32 of Set 12 | hvolsvollur
# Processing Record 33 of Set 12 | asau
# Processing Record 34 of Set 12 | waipawa
# Processing Record 35 of Set 12 | sistranda
# Processing Record 36 of Set 12 | nouadhibou
# Processing Record 37 of Set 12 | karabuk
# Processing Record 38 of Set 12 | arya
# Processing Record 39 of Set 12 | san cristobal
# Processing Record 40 of Set 12 | tacoronte
# Processing Record 41 of Set 12 | trelew
# Processing Record 42 of Set 12 | sayula
# Processing Record 43 of Set 12 | churapcha
# Processing Record 44 of Set 12 | astolfo dutra
# Processing Record 45 of Set 12 | grandview
# Processing Record 46 of Set 12 | ostrovnoy
# Processing Record 47 of Set 12 | anchorage
# Processing Record 48 of Set 12 | zaozerne
# Processing Record 49 of Set 12 | bafoulabe
# Processing Record 50 of Set 12 | shimanovsk
# Processing Record 1 of Set 13 | sovetskoye
# Processing Record 2 of Set 13 | jamsa
# Processing Record 3 of Set 13 | bagdarin
# Processing Record 4 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 5 of Set 13 | phan thiet
# Processing Record 6 of Set 13 | krotoszyn
# Processing Record 7 of Set 13 | cam ranh
# Processing Record 8 of Set 13 | tyazhinskiy
# Processing Record 9 of Set 13 | lemesos
# City not found. Skipping...
# Processing Record 10 of Set 13 | peniche
# Processing Record 11 of Set 13 | lazarev
# Processing Record 12 of Set 13 | pimenta bueno
# Processing Record 13 of Set 13 | dalvik
# Processing Record 14 of Set 13 | tuatapere
# Processing Record 15 of Set 13 | belyy
# Processing Record 16 of Set 13 | okato
# Processing Record 17 of Set 13 | huarmey
# Processing Record 18 of Set 13 | walvis bay
# Processing Record 19 of Set 13 | luebo
# Processing Record 20 of Set 13 | jatai
# Processing Record 21 of Set 13 | tukrah
# Processing Record 22 of Set 13 | christchurch
# Processing Record 23 of Set 13 | seymchan
# Processing Record 24 of Set 13 | brainerd
# Processing Record 25 of Set 13 | myre
# Processing Record 26 of Set 13 | ovre ardal
# Processing Record 27 of Set 13 | svetlaya
# Processing Record 28 of Set 13 | nara
# Processing Record 29 of Set 13 | vao
# Processing Record 30 of Set 13 | yenagoa
# Processing Record 31 of Set 13 | varhaug
# Processing Record 32 of Set 13 | sao gabriel da cachoeira
# Processing Record 33 of Set 13 | raga
# Processing Record 34 of Set 13 | barcelos
# Processing Record 35 of Set 13 | pafos
# Processing Record 36 of Set 13 | buin
# Processing Record 37 of Set 13 | ust-kuyga
# Processing Record 38 of Set 13 | tiarei
# Processing Record 39 of Set 13 | monroe
# Processing Record 40 of Set 13 | chokwe
# Processing Record 41 of Set 13 | lasa
# Processing Record 42 of Set 13 | sena madureira
# Processing Record 43 of Set 13 | kyra
# Processing Record 44 of Set 13 | sehithwa
# Processing Record 45 of Set 13 | saint-joseph
# Processing Record 46 of Set 13 | igarka
# Processing Record 47 of Set 13 | ucluelet
# Processing Record 48 of Set 13 | hami
# Processing Record 49 of Set 13 | jintur
# Processing Record 50 of Set 13 | tombouctou
# Processing Record 1 of Set 14 | alenquer
# Processing Record 2 of Set 14 | cayenne
# Processing Record 3 of Set 14 | whitehorse
# Processing Record 4 of Set 14 | bilma
# Processing Record 5 of Set 14 | pulandian
# Processing Record 6 of Set 14 | tessalit
# Processing Record 7 of Set 14 | nushki
# Processing Record 8 of Set 14 | aykhal
# Processing Record 9 of Set 14 | manokwari
# Processing Record 10 of Set 14 | ternate
# Processing Record 11 of Set 14 | lagunas
# Processing Record 12 of Set 14 | la ronge
# Processing Record 13 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 14 of Set 14 | acajutla
# Processing Record 15 of Set 14 | tomatlan
# Processing Record 16 of Set 14 | chauny
# Processing Record 17 of Set 14 | coralville
# Processing Record 18 of Set 14 | gweta
# Processing Record 19 of Set 14 | praia
# Processing Record 20 of Set 14 | kita
# Processing Record 21 of Set 14 | san quintin
# Processing Record 22 of Set 14 | halifax
# Processing Record 23 of Set 14 | payakumbuh
# Processing Record 24 of Set 14 | kangaatsiaq
# Processing Record 25 of Set 14 | bandarbeyla
# Processing Record 26 of Set 14 | nome
# Processing Record 27 of Set 14 | kungurtug
# Processing Record 28 of Set 14 | jiaozuo
# Processing Record 29 of Set 14 | limbang
# Processing Record 30 of Set 14 | tiruvottiyur
# City not found. Skipping...
# Processing Record 31 of Set 14 | kudahuvadhoo
# Processing Record 32 of Set 14 | suarez
# Processing Record 33 of Set 14 | karmaskaly
# Processing Record 34 of Set 14 | broken hill
# Processing Record 35 of Set 14 | turukhansk
# Processing Record 36 of Set 14 | sohag
# Processing Record 37 of Set 14 | grenada
# Processing Record 38 of Set 14 | makushino
# Processing Record 39 of Set 14 | hearst
# Processing Record 40 of Set 14 | el dorado
# Processing Record 41 of Set 14 | samarai
# Processing Record 42 of Set 14 | jiaxing
# Processing Record 43 of Set 14 | rongcheng
# Processing Record 44 of Set 14 | winkler
# Processing Record 45 of Set 14 | balakhninskiy
# Processing Record 46 of Set 14 | leh
# Processing Record 47 of Set 14 | bogande
# Processing Record 48 of Set 14 | zlotow
# Processing Record 49 of Set 14 | bolshoy lug
# Processing Record 50 of Set 14 | upata
# Processing Record 1 of Set 15 | nienburg
# Processing Record 2 of Set 15 | tommot
# Processing Record 3 of Set 15 | port hardy
# Processing Record 4 of Set 15 | knyaze-volkonskoye
# Processing Record 5 of Set 15 | kampot
# Processing Record 6 of Set 15 | agadir
# Processing Record 7 of Set 15 | alton
# Processing Record 8 of Set 15 | sinjai
# Processing Record 9 of Set 15 | lingao
# Processing Record 10 of Set 15 | frunze
# Processing Record 11 of Set 15 | hithadhoo
# Processing Record 12 of Set 15 | xunchang
# Processing Record 13 of Set 15 | galveston
# Processing Record 14 of Set 15 | palmer
# Processing Record 15 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 16 of Set 15 | susangerd
# Processing Record 17 of Set 15 | bilibino
# Processing Record 18 of Set 15 | takab
# Processing Record 19 of Set 15 | kehl
# Processing Record 20 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 15 | tura
# Processing Record 22 of Set 15 | celestun
# Processing Record 23 of Set 15 | steinbach
# Processing Record 24 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 25 of Set 15 | kilemary
# Processing Record 26 of Set 15 | ngaoundere
# Processing Record 27 of Set 15 | aldama
# Processing Record 28 of Set 15 | manzanillo
# Processing Record 29 of Set 15 | nogliki
# Processing Record 30 of Set 15 | narasannapeta
# Processing Record 31 of Set 15 | lipari
# Processing Record 32 of Set 15 | tautira
# Processing Record 33 of Set 15 | baft
# Processing Record 34 of Set 15 | zhanaozen
# Processing Record 35 of Set 15 | hounde
# Processing Record 36 of Set 15 | ovalle
# Processing Record 37 of Set 15 | guadalupe victoria
# Processing Record 38 of Set 15 | fare
# Processing Record 39 of Set 15 | san juan
# Processing Record 40 of Set 15 | moose factory
# Processing Record 41 of Set 15 | hobyo
# Processing Record 42 of Set 15 | angra
# City not found. Skipping...
# Processing Record 43 of Set 15 | coahuayana
# Processing Record 44 of Set 15 | motygino
# Processing Record 45 of Set 15 | jaciara
# Processing Record 46 of Set 15 | paraiso
# Processing Record 47 of Set 15 | menongue
# Processing Record 48 of Set 15 | husavik
# Processing Record 49 of Set 15 | ugoofaaru
# Processing Record 50 of Set 15 | pangody
# Processing Record 1 of Set 16 | yazykovo
# Processing Record 2 of Set 16 | prince rupert
# Processing Record 3 of Set 16 | parras
# City not found. Skipping...
# Processing Record 4 of Set 16 | skotina
# Processing Record 5 of Set 16 | wyndham
# Processing Record 6 of Set 16 | maragogi
# Processing Record 7 of Set 16 | jardim
# Processing Record 8 of Set 16 | brae
# Processing Record 9 of Set 16 | bonthe
# Processing Record 10 of Set 16 | sangar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 696

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Port Lincoln      AU -34.7333  135.8667     47.77        82         100
# 1      Katangli      RU  51.7102  143.2326     71.53        74          53
# 2         Alice      US  27.7523  -98.0697     81.32        78          20
# 3    Balikpapan      ID  -1.2675  116.8289     76.19        88          40
# 4         Aswan      EG  24.0934   32.9070     96.10        15           0
#
#    Wind Speed       Description
# 0       18.10     moderate rain
# 1        8.19     broken clouds
# 2        6.91        few clouds
# 3        2.30  scattered clouds
# 4       12.66         clear sky

# %%
city_data_df.to_csv('WeatherPy_Database.csv')
